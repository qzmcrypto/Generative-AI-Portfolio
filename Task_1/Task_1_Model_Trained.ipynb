# %%
# !pip install -q transformers datasets

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-85e75c98-94c8-412c-94e4-cf4675989846" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-85e75c98-94c8-412c-94e4-cf4675989846">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
with open("richardIII.txt", "r", encoding="utf-8") as f:
    text = f.read()

chunk_size = 200
texts = [text[i:i+chunk_size] for i in range(0, len(text), chunk_size)]

from datasets import Dataset
raw_dataset = Dataset.from_dict({"text": texts})

# %%
from transformers import AutoTokenizer

tokenizer = AutoTokenizer.from_pretrained("gpt2")
tokenizer.pad_token = tokenizer.eos_token  # Set padding token

def tokenize_function(examples):
    return tokenizer(examples["text"], truncation=True, padding="max_length", max_length=128)

tokenized_dataset = raw_dataset.map(tokenize_function, batched=True, remove_columns=["text"])
# Out:
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# Map:   0%|          | 0/5577 [00:00<?, ? examples/s]

# %%
from transformers import DataCollatorForLanguageModeling

data_collator = DataCollatorForLanguageModeling(
    tokenizer=tokenizer, mlm=False
)

# %%
from transformers import AutoModelForCausalLM, Trainer, TrainingArguments

model = AutoModelForCausalLM.from_pretrained("gpt2")

training_args = TrainingArguments(
    output_dir="./gpt2-richardIII",
    overwrite_output_dir=True,
    num_train_epochs=1,
    per_device_train_batch_size=2,
    save_steps=100,
    save_total_limit=1,
    logging_steps=20,
)

trainer = Trainer(
    model=model,
    args=training_args,
    train_dataset=tokenized_dataset,
    data_collator=data_collator,
)

trainer.train()
# Out:
# wandb: WARNING The `run_name` is currently set to the same value as `TrainingArguments.output_dir`. If this was not intended, please specify a different run name by setting the `TrainingArguments.run_name` parameter.
# wandb: Currently logged in as: qalbezahramashedi (qalbezahramashhadi-codecraft) to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# Tracking run with wandb version 0.21.0
# Run data is saved locally in <code>/content/wandb/run-20250720_103302-th90xx5c</code>
# Syncing run <strong><a href='https://wandb.ai/qalbezahramashhadi-codecraft/huggingface/runs/th90xx5c' target="_blank">./gpt2-richardIII</a></strong> to <a href='https://wandb.ai/qalbezahramashhadi-codecraft/huggingface' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/qalbezahramashhadi-codecraft/huggingface' target="_blank">https://wandb.ai/qalbezahramashhadi-codecraft/huggingface</a>
# ...

# %%
input_text = "Now is the winter of our discontent"
inputs = tokenizer(input_text, return_tensors="pt").input_ids

generated_ids = model.generate(
    inputs,
    max_new_tokens=50,
    do_sample=True,
    top_k=50,
    top_p=0.95,
    temperature=0.9
)

print(tokenizer.decode(generated_ids[0], skip_special_tokens=True))
# Out:
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Now is the winter of our discontent.
#
# DUKE VINCENTIO:
# Nay, let the world be quiet, and I be free.
#
# Provost:
# No, there was the man there, and then no one would
# have put down the

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !ls -ltrh
# Out:
# total 2.3M
# drwxr-xr-x 1 root root 4.0K Jul 16 13:48  sample_data
# -rw-r--r-- 1 root root 1.2M Jul 20 07:47  richardIII.txt
# -rw-r--r-- 1 root root 1.2M Jul 20 10:28 'richardIII (1).txt'
# drwxr-xr-x 4 root root 4.0K Jul 20 10:33  wandb
# drwxr-xr-x 4 root root 4.0K Jul 20 15:03  gpt2-richardIII
# drwx------ 5 root root 4.0K Jul 20 15:05  drive

# %%
# !cp -r ./gpt2-richardIII /content/drive/MyDrive/

# %%
# !ls /content/drive/MyDrive/gpt2-richardIII
# Out:
# checkpoint-2789  runs

# %%
input_text = "The future of AI is the"
inputs = tokenizer(input_text, return_tensors="pt").input_ids

generated_ids = model.generate(inputs, max_new_tokens=50, do_sample=True, top_k=50, top_p=0.95, temperature=0.9)

print(tokenizer.decode(generated_ids[0], skip_special_tokens=True))
# Out:
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The future of AI is the past: the time
# of it is for your own sake.
#
# TRANIO:
# I may speak, not for myself, nor for
# you. But I'll tell you where I am.
#
# HORTENSIO:
